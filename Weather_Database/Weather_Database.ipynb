# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import gmaps
import requests
import random
import time
from datetime import datetime
from citipy import citipy
from config import g_key
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of 2,000 random latitude and longitude.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Store lat & long coordinates to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | karratha
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | chapleau
# Processing Record 4 of Set 1 | khani
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | moerai
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | homer
# Processing Record 19 of Set 1 | layou
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | aanekoski
# Processing Record 24 of Set 1 | beringovskiy
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | kang
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | sitka
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | sergeyevka
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | ciudad bolivar
# Processing Record 39 of Set 1 | bambanglipuro
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | martinsburg
# Processing Record 44 of Set 1 | aksu
# Processing Record 45 of Set 1 | san juan de los morros
# Processing Record 46 of Set 1 | lere
# Processing Record 47 of Set 1 | cabo rojo
# Processing Record 48 of Set 1 | vardo
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | havre-saint-pierre
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | lazaro cardenas
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | moose factory
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | ambilobe
# Processing Record 8 of Set 2 | sistranda
# Processing Record 9 of Set 2 | bay city
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | touros
# Processing Record 13 of Set 2 | hami
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | nemuro
# Processing Record 18 of Set 2 | shetpe
# Processing Record 19 of Set 2 | champerico
# Processing Record 20 of Set 2 | komsomolskiy
# Processing Record 21 of Set 2 | tura
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | paicandu
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | kostomuksha
# Processing Record 31 of Set 2 | lokosovo
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | vangaindrano
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | gushikawa
# Processing Record 37 of Set 2 | kungurtug
# Processing Record 38 of Set 2 | tarhunah
# City not found. Skipping...
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | nicoya
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | sabana abajo
# City not found. Skipping...
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | premia de mar
# Processing Record 45 of Set 2 | fuerte olimpo
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | zhigalovo
# Processing Record 50 of Set 2 | lebanon
# Processing Record 1 of Set 3 | hobyo
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | severo-kurilsk
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | rancho palos verdes
# Processing Record 9 of Set 3 | lahaina
# Processing Record 10 of Set 3 | garowe
# Processing Record 11 of Set 3 | nuuk
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | balarampur
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | rosarito
# Processing Record 16 of Set 3 | lingao
# Processing Record 17 of Set 3 | kavaratti
# Processing Record 18 of Set 3 | cayenne
# Processing Record 19 of Set 3 | punta arenas
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | zhezkazgan
# Processing Record 22 of Set 3 | poya
# Processing Record 23 of Set 3 | iranshahr
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | verkhnevilyuysk
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | marsabit
# Processing Record 28 of Set 3 | atasu
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | vostok
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | cocachacra
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | lahij
# Processing Record 37 of Set 3 | krasnokholm
# Processing Record 38 of Set 3 | hargeysa
# Processing Record 39 of Set 3 | sri aman
# Processing Record 40 of Set 3 | coahuayana
# Processing Record 41 of Set 3 | meulaboh
# Processing Record 42 of Set 3 | linkou
# Processing Record 43 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 45 of Set 3 | nishihara
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | mandera
# Processing Record 48 of Set 3 | fairbanks
# Processing Record 49 of Set 3 | karasjok
# Processing Record 50 of Set 3 | sesheke
# Processing Record 1 of Set 4 | ouadda
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | paipa
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | manzhouli
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | alta
# Processing Record 9 of Set 4 | saint-pierre
# Processing Record 10 of Set 4 | umea
# Processing Record 11 of Set 4 | thunder bay
# Processing Record 12 of Set 4 | semikarakorsk
# Processing Record 13 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 4 | labuhan
# Processing Record 15 of Set 4 | shingu
# Processing Record 16 of Set 4 | prykolotne
# Processing Record 17 of Set 4 | saint anthony
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | shaghat
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | cookeville
# Processing Record 22 of Set 4 | lethem
# Processing Record 23 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 4 | bratsk
# Processing Record 25 of Set 4 | tateyama
# Processing Record 26 of Set 4 | grand gaube
# Processing Record 27 of Set 4 | jiuquan
# Processing Record 28 of Set 4 | la plata
# Processing Record 29 of Set 4 | pangai
# Processing Record 30 of Set 4 | fort nelson
# Processing Record 31 of Set 4 | port hedland
# Processing Record 32 of Set 4 | polyarnyy
# Processing Record 33 of Set 4 | luau
# Processing Record 34 of Set 4 | izmalkovo
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | wadi musa
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | hirara
# Processing Record 39 of Set 4 | zhanakorgan
# Processing Record 40 of Set 4 | leh
# Processing Record 41 of Set 4 | chifeng
# Processing Record 42 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 4 | skibbereen
# Processing Record 44 of Set 4 | sertanopolis
# Processing Record 45 of Set 4 | malko tarnovo
# Processing Record 46 of Set 4 | vrangel
# Processing Record 47 of Set 4 | dikson
# Processing Record 48 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 4 | saint-philippe
# Processing Record 50 of Set 4 | bredasdorp
# Processing Record 1 of Set 5 | cidreira
# Processing Record 2 of Set 5 | benjamin constant
# Processing Record 3 of Set 5 | saint-prosper
# Processing Record 4 of Set 5 | port alfred
# Processing Record 5 of Set 5 | powell river
# Processing Record 6 of Set 5 | pisco
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | chicama
# Processing Record 9 of Set 5 | araouane
# Processing Record 10 of Set 5 | terrace bay
# Processing Record 11 of Set 5 | mariakani
# Processing Record 12 of Set 5 | bama
# Processing Record 13 of Set 5 | ulverstone
# Processing Record 14 of Set 5 | lubango
# Processing Record 15 of Set 5 | bodden town
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | paamiut
# Processing Record 18 of Set 5 | chumikan
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | taoudenni
# Processing Record 21 of Set 5 | bethanien
# Processing Record 22 of Set 5 | kozhevnikovo
# Processing Record 23 of Set 5 | vestmannaeyjar
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | kieta
# Processing Record 26 of Set 5 | otane
# Processing Record 27 of Set 5 | maihar
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | pangnirtung
# Processing Record 30 of Set 5 | iquique
# Processing Record 31 of Set 5 | tres lagoas
# Processing Record 32 of Set 5 | bubaque
# Processing Record 33 of Set 5 | newport
# Processing Record 34 of Set 5 | new norfolk
# Processing Record 35 of Set 5 | saquarema
# Processing Record 36 of Set 5 | ormara
# Processing Record 37 of Set 5 | abapo
# Processing Record 38 of Set 5 | los llanos de aridane
# Processing Record 39 of Set 5 | tucupita
# Processing Record 40 of Set 5 | brunswick
# Processing Record 41 of Set 5 | klokkarvik
# City not found. Skipping...
# Processing Record 42 of Set 5 | mosquera
# Processing Record 43 of Set 5 | nisia floresta
# Processing Record 44 of Set 5 | portland
# Processing Record 45 of Set 5 | iberia
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | kushiro
# Processing Record 48 of Set 5 | keti bandar
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | kandi
# Processing Record 1 of Set 6 | ardesen
# Processing Record 2 of Set 6 | santa rosa
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | prieska
# Processing Record 5 of Set 6 | sandomierz
# Processing Record 6 of Set 6 | alfenas
# Processing Record 7 of Set 6 | billings
# Processing Record 8 of Set 6 | santa maria
# Processing Record 9 of Set 6 | jizan
# Processing Record 10 of Set 6 | phuket
# Processing Record 11 of Set 6 | san pedro buenavista
# Processing Record 12 of Set 6 | yellowknife
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | rundu
# Processing Record 15 of Set 6 | caravelas
# Processing Record 16 of Set 6 | antalaha
# Processing Record 17 of Set 6 | makakilo city
# Processing Record 18 of Set 6 | jiayuguan
# Processing Record 19 of Set 6 | adrar
# Processing Record 20 of Set 6 | zhuanghe
# Processing Record 21 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | honiara
# Processing Record 24 of Set 6 | eseka
# Processing Record 25 of Set 6 | muyezerskiy
# Processing Record 26 of Set 6 | fairhope
# Processing Record 27 of Set 6 | kuah
# Processing Record 28 of Set 6 | samokov
# Processing Record 29 of Set 6 | ixtapa
# Processing Record 30 of Set 6 | semey
# Processing Record 31 of Set 6 | kaduqli
# Processing Record 32 of Set 6 | kotka
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | inuvik
# Processing Record 35 of Set 6 | beloha
# Processing Record 36 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 6 | hoa binh
# Processing Record 38 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | brae
# Processing Record 41 of Set 6 | georgetown
# Processing Record 42 of Set 6 | superior
# Processing Record 43 of Set 6 | bonavista
# Processing Record 44 of Set 6 | kenai
# Processing Record 45 of Set 6 | celestun
# Processing Record 46 of Set 6 | axim
# Processing Record 47 of Set 6 | naze
# Processing Record 48 of Set 6 | mumford
# Processing Record 49 of Set 6 | maua
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | ibimirim
# Processing Record 2 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 3 of Set 7 | makat
# Processing Record 4 of Set 7 | marawi
# Processing Record 5 of Set 7 | vila velha
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | khirkiya
# Processing Record 8 of Set 7 | lewistown
# Processing Record 9 of Set 7 | sorland
# Processing Record 10 of Set 7 | koumac
# Processing Record 11 of Set 7 | morro bay
# Processing Record 12 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 7 | udachnyy
# Processing Record 14 of Set 7 | cilegon
# Processing Record 15 of Set 7 | sobolevo
# Processing Record 16 of Set 7 | drochtersen
# Processing Record 17 of Set 7 | pleasanton
# Processing Record 18 of Set 7 | zharkent
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | gravdal
# Processing Record 21 of Set 7 | diego de almagro
# Processing Record 22 of Set 7 | marfino
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | port blair
# Processing Record 25 of Set 7 | lookan
# Processing Record 26 of Set 7 | lakes entrance
# Processing Record 27 of Set 7 | machalpur
# Processing Record 28 of Set 7 | dingle
# Processing Record 29 of Set 7 | nadvoitsy
# Processing Record 30 of Set 7 | carauari
# Processing Record 31 of Set 7 | yankton
# Processing Record 32 of Set 7 | lichinga
# Processing Record 33 of Set 7 | anadyr
# Processing Record 34 of Set 7 | grindavik
# Processing Record 35 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 7 | asau
# Processing Record 37 of Set 7 | san patricio
# Processing Record 38 of Set 7 | port-cartier
# Processing Record 39 of Set 7 | sinjar
# Processing Record 40 of Set 7 | kaitangata
# Processing Record 41 of Set 7 | chapais
# Processing Record 42 of Set 7 | tigil
# Processing Record 43 of Set 7 | arraial do cabo
# Processing Record 44 of Set 7 | kidal
# Processing Record 45 of Set 7 | westport
# Processing Record 46 of Set 7 | ahipara
# Processing Record 47 of Set 7 | jalu
# Processing Record 48 of Set 7 | kribi
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 8 | constitucion
# Processing Record 3 of Set 8 | antofagasta
# Processing Record 4 of Set 8 | sindor
# Processing Record 5 of Set 8 | trairi
# Processing Record 6 of Set 8 | narsaq
# Processing Record 7 of Set 8 | cape town
# Processing Record 8 of Set 8 | hajnowka
# Processing Record 9 of Set 8 | aninoasa
# Processing Record 10 of Set 8 | giyani
# Processing Record 11 of Set 8 | whitehorse
# Processing Record 12 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 8 | sambava
# Processing Record 14 of Set 8 | mirnyy
# Processing Record 15 of Set 8 | torbay
# Processing Record 16 of Set 8 | umm lajj
# Processing Record 17 of Set 8 | freeport
# Processing Record 18 of Set 8 | san quintin
# Processing Record 19 of Set 8 | bam
# Processing Record 20 of Set 8 | cabo san lucas
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | pitimbu
# Processing Record 23 of Set 8 | olafsvik
# Processing Record 24 of Set 8 | flinders
# Processing Record 25 of Set 8 | nelson
# Processing Record 26 of Set 8 | qarchi gak
# Processing Record 27 of Set 8 | mount gambier
# Processing Record 28 of Set 8 | mahibadhoo
# Processing Record 29 of Set 8 | hamilton
# Processing Record 30 of Set 8 | tuatapere
# Processing Record 31 of Set 8 | lenger
# Processing Record 32 of Set 8 | sioux lookout
# Processing Record 33 of Set 8 | college
# Processing Record 34 of Set 8 | mazamari
# Processing Record 35 of Set 8 | tessalit
# Processing Record 36 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 8 | mezen
# Processing Record 38 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 39 of Set 8 | banjar
# Processing Record 40 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 8 | lindi
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | merced
# Processing Record 44 of Set 8 | teguldet
# Processing Record 45 of Set 8 | bambous virieux
# Processing Record 46 of Set 8 | saint-francois
# Processing Record 47 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 8 | wajima
# Processing Record 49 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 8 | nebolchi
# Processing Record 1 of Set 9 | lebu
# Processing Record 2 of Set 9 | aasiaat
# Processing Record 3 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 9 | parati
# Processing Record 5 of Set 9 | loiza
# Processing Record 6 of Set 9 | neiafu
# Processing Record 7 of Set 9 | kavant
# City not found. Skipping...
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | keningau
# Processing Record 10 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 11 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 9 | marsh harbour
# Processing Record 14 of Set 9 | cansancao
# Processing Record 15 of Set 9 | boende
# Processing Record 16 of Set 9 | cururupu
# Processing Record 17 of Set 9 | ust-maya
# Processing Record 18 of Set 9 | srednekolymsk
# Processing Record 19 of Set 9 | lucapa
# Processing Record 20 of Set 9 | rocha
# Processing Record 21 of Set 9 | hovd
# Processing Record 22 of Set 9 | nola
# Processing Record 23 of Set 9 | sterling
# Processing Record 24 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 9 | hualmay
# Processing Record 26 of Set 9 | merauke
# Processing Record 27 of Set 9 | tahe
# Processing Record 28 of Set 9 | lodja
# Processing Record 29 of Set 9 | severo-yeniseyskiy
# Processing Record 30 of Set 9 | spearfish
# Processing Record 31 of Set 9 | vitim
# Processing Record 32 of Set 9 | kavieng
# Processing Record 33 of Set 9 | tet
# Processing Record 34 of Set 9 | ahuimanu
# Processing Record 35 of Set 9 | dakar
# Processing Record 36 of Set 9 | puerto escondido
# Processing Record 37 of Set 9 | kaspiysk
# Processing Record 38 of Set 9 | matelandia
# Processing Record 39 of Set 9 | gudivada
# Processing Record 40 of Set 9 | vaitape
# Processing Record 41 of Set 9 | eureka
# Processing Record 42 of Set 9 | corning
# Processing Record 43 of Set 9 | kafr sawm
# Processing Record 44 of Set 9 | vao
# Processing Record 45 of Set 9 | panubigan
# Processing Record 46 of Set 9 | juba
# Processing Record 47 of Set 9 | avera
# Processing Record 48 of Set 9 | belaya gora
# Processing Record 49 of Set 9 | ayagoz
# Processing Record 50 of Set 9 | arona
# Processing Record 1 of Set 10 | bireun
# Processing Record 2 of Set 10 | half moon bay
# Processing Record 3 of Set 10 | san carlos de bariloche
# Processing Record 4 of Set 10 | matamoros
# Processing Record 5 of Set 10 | talcahuano
# Processing Record 6 of Set 10 | solok
# Processing Record 7 of Set 10 | codajas
# Processing Record 8 of Set 10 | namtsy
# Processing Record 9 of Set 10 | anloga
# Processing Record 10 of Set 10 | tocopilla
# Processing Record 11 of Set 10 | port hardy
# Processing Record 12 of Set 10 | uberaba
# Processing Record 13 of Set 10 | port augusta
# Processing Record 14 of Set 10 | aljezur
# Processing Record 15 of Set 10 | san ignacio
# Processing Record 16 of Set 10 | baruun-urt
# Processing Record 17 of Set 10 | batsfjord
# Processing Record 18 of Set 10 | dnestrovsc
# Processing Record 19 of Set 10 | okhotsk
# Processing Record 20 of Set 10 | nueva guinea
# Processing Record 21 of Set 10 | dong hoi
# Processing Record 22 of Set 10 | kinsale
# Processing Record 23 of Set 10 | neuquen
# Processing Record 24 of Set 10 | leningradskiy
# Processing Record 25 of Set 10 | benjamin aceval
# Processing Record 26 of Set 10 | solnechnyy
# Processing Record 27 of Set 10 | atar
# Processing Record 28 of Set 10 | evensk
# Processing Record 29 of Set 10 | ribas do rio pardo
# Processing Record 30 of Set 10 | orangeburg
# Processing Record 31 of Set 10 | wakkanai
# Processing Record 32 of Set 10 | hailey
# Processing Record 33 of Set 10 | cao bang
# Processing Record 34 of Set 10 | cascavel
# Processing Record 35 of Set 10 | karur
# Processing Record 36 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 37 of Set 10 | bazarnyye mataki
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | finschhafen
# Processing Record 40 of Set 10 | tatawin
# Processing Record 41 of Set 10 | nador
# Processing Record 42 of Set 10 | shimoda
# Processing Record 43 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 10 | marshfield
# Processing Record 46 of Set 10 | princeton
# Processing Record 47 of Set 10 | bremerton
# Processing Record 48 of Set 10 | sorong
# Processing Record 49 of Set 10 | cabedelo
# Processing Record 50 of Set 10 | bukachacha
# Processing Record 1 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 2 of Set 11 | toktogul
# Processing Record 3 of Set 11 | krasnyy kut
# Processing Record 4 of Set 11 | qandala
# Processing Record 5 of Set 11 | laguna de perlas
# Processing Record 6 of Set 11 | swan hill
# Processing Record 7 of Set 11 | zhigansk
# Processing Record 8 of Set 11 | ocampo
# Processing Record 9 of Set 11 | kobojango
# City not found. Skipping...
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | kholtoson
# Processing Record 12 of Set 11 | ishigaki
# Processing Record 13 of Set 11 | neftekamsk
# Processing Record 14 of Set 11 | barstow
# Processing Record 15 of Set 11 | bogovarovo
# Processing Record 16 of Set 11 | auki
# Processing Record 17 of Set 11 | gizo
# Processing Record 18 of Set 11 | batagay-alyta
# Processing Record 19 of Set 11 | the valley
# Processing Record 20 of Set 11 | cozumel
# Processing Record 21 of Set 11 | presidencia roque saenz pena
# Processing Record 22 of Set 11 | prince rupert
# Processing Record 23 of Set 11 | curuca
# Processing Record 24 of Set 11 | ambon
# Processing Record 25 of Set 11 | waipawa
# Processing Record 26 of Set 11 | kudligi
# Processing Record 27 of Set 11 | kholm
# Processing Record 28 of Set 11 | bulgan
# Processing Record 29 of Set 11 | bang krathum
# Processing Record 30 of Set 11 | kastamonu
# Processing Record 31 of Set 11 | valparaiso
# Processing Record 32 of Set 11 | langxiang
# Processing Record 33 of Set 11 | tautira
# Processing Record 34 of Set 11 | egvekinot
# Processing Record 35 of Set 11 | macapa
# Processing Record 36 of Set 11 | saryg-sep
# Processing Record 37 of Set 11 | kodinsk
# Processing Record 38 of Set 11 | januaria
# Processing Record 39 of Set 11 | hitoyoshi
# Processing Record 40 of Set 11 | guerrero negro
# Processing Record 41 of Set 11 | gaoual
# Processing Record 42 of Set 11 | morogoro
# Processing Record 43 of Set 11 | suslovo
# Processing Record 44 of Set 11 | huntsville
# Processing Record 45 of Set 11 | tuy hoa
# Processing Record 46 of Set 11 | ekhabi
# Processing Record 47 of Set 11 | bereda
# Processing Record 48 of Set 11 | morant bay
# Processing Record 49 of Set 11 | korla
# Processing Record 50 of Set 11 | den helder
# Processing Record 1 of Set 12 | santarem
# Processing Record 2 of Set 12 | nizhniy chir
# Processing Record 3 of Set 12 | port-gentil
# Processing Record 4 of Set 12 | kwinana
# Processing Record 5 of Set 12 | ust-ishim
# Processing Record 6 of Set 12 | miguel calmon
# Processing Record 7 of Set 12 | tiznit
# Processing Record 8 of Set 12 | burnie
# Processing Record 9 of Set 12 | nanakuli
# Processing Record 10 of Set 12 | pilar
# Processing Record 11 of Set 12 | jian
# Processing Record 12 of Set 12 | la primavera
# Processing Record 13 of Set 12 | hofn
# Processing Record 14 of Set 12 | farafangana
# Processing Record 15 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | verkh-usugli
# Processing Record 17 of Set 12 | altamira
# Processing Record 18 of Set 12 | yantal
# Processing Record 19 of Set 12 | hefei
# Processing Record 20 of Set 12 | walvis bay
# Processing Record 21 of Set 12 | nalut
# Processing Record 22 of Set 12 | bilma
# Processing Record 23 of Set 12 | henties bay
# Processing Record 24 of Set 12 | itoman
# Processing Record 25 of Set 12 | kinshasa
# Processing Record 26 of Set 12 | jieshi
# Processing Record 27 of Set 12 | shatsk
# Processing Record 28 of Set 12 | qaqortoq
# Processing Record 29 of Set 12 | klyuchi
# Processing Record 30 of Set 12 | sechura
# Processing Record 31 of Set 12 | belyy yar
# Processing Record 32 of Set 12 | quelimane
# Processing Record 33 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 12 | maceio
# Processing Record 35 of Set 12 | broken hill
# Processing Record 36 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 12 | havoysund
# Processing Record 38 of Set 12 | pemangkat
# Processing Record 39 of Set 12 | kinkala
# Processing Record 40 of Set 12 | harper
# Processing Record 41 of Set 12 | alofi
# Processing Record 42 of Set 12 | mahina
# Processing Record 43 of Set 12 | kuldur
# Processing Record 44 of Set 12 | isfana
# Processing Record 45 of Set 12 | okitipupa
# Processing Record 46 of Set 12 | fort-shevchenko
# Processing Record 47 of Set 12 | rovaniemi
# Processing Record 48 of Set 12 | bujaru
# Processing Record 49 of Set 12 | phan thiet
# Processing Record 50 of Set 12 | guiyang
# Processing Record 1 of Set 13 | aswan
# Processing Record 2 of Set 13 | san policarpo
# Processing Record 3 of Set 13 | ballina
# Processing Record 4 of Set 13 | salinopolis
# Processing Record 5 of Set 13 | bela
# Processing Record 6 of Set 13 | byron bay
# Processing Record 7 of Set 13 | galesong
# Processing Record 8 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 13 | keshan
# City not found. Skipping...
# Processing Record 10 of Set 13 | opuwo
# Processing Record 11 of Set 13 | san andres
# Processing Record 12 of Set 13 | barra de sao francisco
# Processing Record 13 of Set 13 | marzuq
# Processing Record 14 of Set 13 | sabha
# Processing Record 15 of Set 13 | abu samrah
# Processing Record 16 of Set 13 | gambela
# Processing Record 17 of Set 13 | waterloo
# Processing Record 18 of Set 13 | general pico
# Processing Record 19 of Set 13 | wenatchee
# Processing Record 20 of Set 13 | hillsborough
# Processing Record 21 of Set 13 | pandan
# Processing Record 22 of Set 13 | senanga
# Processing Record 23 of Set 13 | bowen
# Processing Record 24 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 13 | aripuana
# Processing Record 26 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 13 | port keats
# Processing Record 28 of Set 13 | krasnoselkup
# Processing Record 29 of Set 13 | kruisfontein
# Processing Record 30 of Set 13 | pallisa
# Processing Record 31 of Set 13 | lukovetskiy
# Processing Record 32 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 13 | mikhaylovka
# Processing Record 34 of Set 13 | comodoro rivadavia
# Processing Record 35 of Set 13 | seymchan
# Processing Record 36 of Set 13 | san cristobal
# Processing Record 37 of Set 13 | pochutla
# Processing Record 38 of Set 13 | burns lake
# Processing Record 39 of Set 13 | riyadh
# Processing Record 40 of Set 13 | lamu
# Processing Record 41 of Set 13 | shiyan
# Processing Record 42 of Set 13 | vallenar
# Processing Record 43 of Set 13 | camana
# Processing Record 44 of Set 13 | donskoy
# Processing Record 45 of Set 13 | ilhabela
# Processing Record 46 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 13 | yerbogachen
# Processing Record 48 of Set 13 | daru
# Processing Record 49 of Set 13 | silifke
# Processing Record 50 of Set 13 | karakol
# Processing Record 1 of Set 14 | strezhevoy
# Processing Record 2 of Set 14 | tazovskiy
# Processing Record 3 of Set 14 | jerome
# Processing Record 4 of Set 14 | steenwijk
# Processing Record 5 of Set 14 | palmer
# Processing Record 6 of Set 14 | maniitsoq
# Processing Record 7 of Set 14 | dandong
# Processing Record 8 of Set 14 | praia da vitoria
# Processing Record 9 of Set 14 | muzquiz
# City not found. Skipping...
# Processing Record 10 of Set 14 | shubarshi
# Processing Record 11 of Set 14 | sydney
# Processing Record 12 of Set 14 | sao luiz gonzaga
# Processing Record 13 of Set 14 | san ramon
# Processing Record 14 of Set 14 | khorixas
# Processing Record 15 of Set 14 | uruzgan
# Processing Record 16 of Set 14 | nema
# Processing Record 17 of Set 14 | dongsheng
# Processing Record 18 of Set 14 | foam lake
# Processing Record 19 of Set 14 | flin flon
# Processing Record 20 of Set 14 | lewiston
# Processing Record 21 of Set 14 | gat
# Processing Record 22 of Set 14 | point pedro
# Processing Record 23 of Set 14 | wabrzezno
# Processing Record 24 of Set 14 | frontera
# Processing Record 25 of Set 14 | mahanoro
# Processing Record 26 of Set 14 | sholokhovskiy
# Processing Record 27 of Set 14 | san buenaventura
# Processing Record 28 of Set 14 | inverness
# Processing Record 29 of Set 14 | parabel
# Processing Record 30 of Set 14 | mbuji-mayi
# Processing Record 31 of Set 14 | almeirim
# Processing Record 32 of Set 14 | huarmey
# Processing Record 33 of Set 14 | avila
# Processing Record 34 of Set 14 | lakatoro
# Processing Record 35 of Set 14 | muisne
# Processing Record 36 of Set 14 | itigi
# Processing Record 37 of Set 14 | tilichiki
# Processing Record 38 of Set 14 | ramacca
# Processing Record 39 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 14 | isangel
# Processing Record 41 of Set 14 | lashio
# Processing Record 42 of Set 14 | bull savanna
# Processing Record 43 of Set 14 | hofu
# Processing Record 44 of Set 14 | robertsport
# Processing Record 45 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 14 | richards bay
# Processing Record 47 of Set 14 | port lincoln
# Processing Record 48 of Set 14 | milevsko
# Processing Record 49 of Set 14 | dunedin
# Processing Record 50 of Set 14 | grodig
# Processing Record 1 of Set 15 | sabla
# Processing Record 2 of Set 15 | nome
# Processing Record 3 of Set 15 | singuilucan
# Processing Record 4 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 15 | progreso
# Processing Record 6 of Set 15 | norfolk
# Processing Record 7 of Set 15 | coihaique
# Processing Record 8 of Set 15 | sosnovo-ozerskoye
# Processing Record 9 of Set 15 | solton
# Processing Record 10 of Set 15 | acarau
# Processing Record 11 of Set 15 | roald
# Processing Record 12 of Set 15 | cervo
# Processing Record 13 of Set 15 | chimoio
# Processing Record 14 of Set 15 | trinidad
# Processing Record 15 of Set 15 | kisangani
# Processing Record 16 of Set 15 | yar-sale
# Processing Record 17 of Set 15 | aykino
# Processing Record 18 of Set 15 | nahrin
# Processing Record 19 of Set 15 | kautokeino
# Processing Record 20 of Set 15 | palaikastron
# Processing Record 21 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 15 | kitami
# Processing Record 23 of Set 15 | port macquarie
# Processing Record 24 of Set 15 | mogzon
# Processing Record 25 of Set 15 | at-bashi
# Processing Record 26 of Set 15 | panji
# Processing Record 27 of Set 15 | raudeberg
# Processing Record 28 of Set 15 | asosa
# Processing Record 29 of Set 15 | lae
# Processing Record 30 of Set 15 | gold coast
# Processing Record 31 of Set 15 | pastos bons
# Processing Record 32 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 33 of Set 15 | cabra
# Processing Record 34 of Set 15 | les herbiers
# Processing Record 35 of Set 15 | tashtyp
# Processing Record 36 of Set 15 | kizema
# Processing Record 37 of Set 15 | darnah
# Processing Record 38 of Set 15 | saint-augustin
# Processing Record 39 of Set 15 | itarema
# Processing Record 40 of Set 15 | ouargaye
# Processing Record 41 of Set 15 | revda
# Processing Record 42 of Set 15 | bilibino
# Processing Record 43 of Set 15 | bojnurd
# Processing Record 44 of Set 15 | acari
# Processing Record 45 of Set 15 | tabou
# Processing Record 46 of Set 15 | shenjiamen
# Processing Record 47 of Set 15 | wajir
# Processing Record 48 of Set 15 | iracoubo
# Processing Record 49 of Set 15 | bairiki
# Processing Record 50 of Set 15 | xanlar
# Processing Record 1 of Set 16 | bay roberts
# Processing Record 2 of Set 16 | alice springs
# Processing Record 3 of Set 16 | clyde river
# Processing Record 4 of Set 16 | skjervoy
# Processing Record 5 of Set 16 | alamosa
# Processing Record 6 of Set 16 | sehithwa
# Processing Record 7 of Set 16 | fare
# Processing Record 8 of Set 16 | ayacucho
# Processing Record 9 of Set 16 | usinsk
# Processing Record 10 of Set 16 | moussoro
# Processing Record 11 of Set 16 | kirakira
# Processing Record 12 of Set 16 | yatou
# Processing Record 13 of Set 16 | houston
# Processing Record 14 of Set 16 | naugarzan
# City not found. Skipping...
# Processing Record 15 of Set 16 | changping
# Processing Record 16 of Set 16 | karpogory
# Processing Record 17 of Set 16 | wladyslawowo
# Processing Record 18 of Set 16 | lugovoy
# Processing Record 19 of Set 16 | berdigestyakh
# Processing Record 20 of Set 16 | nouadhibou
# Processing Record 21 of Set 16 | valley city
# Processing Record 22 of Set 16 | cumana
# Processing Record 23 of Set 16 | general roca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Karratha      AU -20.7377  116.8463     80.51        47          74
# 1       Albany      US  42.6001  -73.9662     40.32        54           3
# 2     Chapleau      CA  47.8405  -83.4034     37.49        81          90
# 3        Khani      GE  41.9563   42.9566     38.77        95          97
# 4      Rikitea      PF -23.1203 -134.9692     76.59        78          18
# 5        Tiksi      RU  71.6872  128.8694     -7.42        92         100
# 6    Hithadhoo      MV  -0.6000   73.0833     81.81        76         100
# 7  Tuktoyaktuk      CA  69.4541 -133.0374    -23.80        69          20
# 8     Thompson      CA  55.7435  -97.8558      4.62        84          83
# 9        Vaini      TO -21.2000 -175.2000     84.36        84          75
#
#    Wind Speed Current Description
# 0        9.66       broken clouds
# 1        3.51           clear sky
# 2        4.61     overcast clouds
# 3        1.50     overcast clouds
# 4       15.12          few clouds
# 5        5.97     overcast clouds
# 6       18.50     overcast clouds
# 7        6.91          few clouds
# 8       10.40       broken clouds
# 9        4.61       broken clouds

# %%
# export dataframe as csv
csv_file = "WeatherPy_Database.csv"
city_data_df.to_csv(csv_file, index_label="City_ID")
